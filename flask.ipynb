# %%
import os
os.makedirs("templates", exist_ok=True)
os.makedirs("static/images", exist_ok=True)
os.makedirs("static/css", exist_ok=True)

files = [
    "app.py", "models.py", "forms.py", "requirements.txt",
    "templates/base.html", "templates/home.html", "templates/about.html",
    "templates/contact.html", "templates/login.html", "templates/register.html",
    "templates/students.html"
]

for file in files:
    with open(file, "w") as f:
        pass 
print("Project structure and files created.")
# Out:
# Project structure and files created.
